# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### Імпортуємо, збережені у віртуальному середовищі, змінні

# %%
# %store -r results

# %%
sns.barplot(x=results[0].city, y=results[0].total_volume, palette='flare')
plt.title('Відсортувати кількість проданого алкоголю в літрах за містами')
plt.show()

# %%
sns.set_theme(palette='Blues')
plt.pie(x=results[1].retail, labels=results[1].store_name, autopct='%.0f%%')
plt.show()

# %%
sns.set_theme(palette='rocket')
sns.lineplot(x=results[2].sale_date, y=results[2].total_retail)
plt.title('Відсортувати сумарні продажі за часом')
plt.show()
